# %% [markdown]
# # **Number classification algorithm**

# %% [markdown]
# # Read database
#
# Functions used to read the database (train and test) from MNIST and also from the csv file generated with the images captured from the pico camera

# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import itertools

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.grid_search import RandomizedSearchCV
from sklearn.grid_search import GridSearchCV

from sklearn.externals import joblib
import string

# %%
class Digit:
    def __init__(self, data, target):
        self.target = target
        self.width  = int(np.sqrt(len(data)))
        self.image  = data.reshape(self.width, self.width)
        self.features = {'var' : 0,
                         'std' : 0,
                         'mean_grad_M' : 0,
                         'std_grad_M'  : 0,
                         'mean_grad_D' : 0,
                         'std_grad_D'  : 0,
                         'mean_PC_X'   : 0,
                         'std_PC_X'    : 0,
                         'active_PC_X' : 0,
                         'mean_PC_Y'   : 0,
                         'std_PC_Y'    : 0,
                         'active_PC_Y' : 0}
        self.computeFeatures()
    
    def computeFeatures(self):
        # Feature computation
        mag, ang = sobel(self.image)
        pcx, pcy = pixel_count(self.image)
        
        self.features['var'] = np.var(self.image)
        self.features['std'] = np.std(self.image)
        self.features['mean_grad_M'] = np.mean(mag)
        self.features['std_grad_M'] =  np.std(mag)
        self.features['mean_grad_D'] = np.mean(ang)
        self.features['std_grad_D'] =  np.std(ang)
        self.features['mean_PC_X'] =   np.mean(pcx)
        self.features['std_PC_X'] =    np.std(pcx)
        self.features['active_PC_X'] = np.count_nonzero(pcx)
        self.features['mean_PC_Y'] =   np.mean(pcy)
        self.features['std_PC_Y'] =    np.std(pcy)
        self.features['active_PC_Y'] = np.count_nonzero(pcy) 
  
    def __print__(self):
        print("Digit target: "+str(self.target))
        print("Digit features:")
        print(self.features)
        print("Digit image:")
        plt.gray()
        plt.matshow(self.image) 
        plt.show()

# %%
def sobel(image):
    w = len(image)
    kernel_x = np.array([ [ 1, 0,-1],
                          [ 2, 0,-2],
                          [ 1, 0,-1] ])

    kernel_y = np.array([ [ 1, 2, 1],
                          [ 0, 0, 0],
                          [-1,-2,-1] ])
    
    grad_x = np.zeros([w - 2, w - 2])
    grad_y = np.zeros([w - 2, w - 2])
    
    for i in range(w - 2):
        for j in range(w - 2):
            grad_x[i, j] = sum(sum(image[i : i + 3, j : j + 3] * kernel_x))
            grad_y[i, j] = sum(sum(image[i : i + 3, j : j + 3] * kernel_y))
            if grad_x[i, j] == 0:
                grad_x[i, j] = 0.000001 
    
    mag = np.sqrt(grad_y ** 2 + grad_x ** 2)
    ang = np.arctan(grad_y / (grad_x + np.finfo(float).eps))
  
    # Gradient computation
  
    return [mag,ang]

def pixel_count(image):
    pc_x = np.zeros(len(image))
    pc_y = np.zeros(len(image))
  
    # Pixel count computation
    for i in range(len(image)):
        pc_x[i] = np.count_nonzero(image[i, :])
        pc_y[i] = np.count_nonzero(image[:, i])

    return [pc_x, pc_y]

# %%
class Dataset:
    def __init__(self, array, length):  
        self.array = array
        self.length = length
        self.digits = []
        self.digits = self.createDigits()
        self.raw_features = [[float(f) for f in dig.features.values()] for dig in self.digits]
        self.raw_targets  = [[self.digits[i].target] for i in range(self.length)]
  
    def createDigits(self):
        digits = []
        for row in self.array:
            digits.append(Digit(np.array(row[:-1]), row[-1]))
        return digits

# %% [markdown]
# # Generate datasets

# %%
# n : percent of the number of lines in the data base use as array set
def load_data_set(array, n):
    dataset = Dataset(array[:int(n * len(array))], int(n * len(array)))
    return dataset

# %%
# %%time

#Load the database (.npy) files 
img_array_test = np.load('./../../test.npy')
# Out:
# CPU times: user 1.23 ms, sys: 16.6 ms, total: 17.9 ms
# Wall time: 16.5 ms

# %%
# %%time 

print("Creating testing dataset")
print("Number of the lines in the test dataset: " + str(len(img_array_test)))
testing_set = load_data_set(img_array_test, 1)
print ("Number of the lines in the test dataset: " + str(testing_set.length))
print ("\nFinished creating test dataset\n")
# Out:
# Creating testing dataset
# Number of the lines in the test dataset: 6150
# Number of the lines in the test dataset: 6150
#
# Finished creating test dataset
#
# CPU times: user 1min 9s, sys: 174 ms, total: 1min 9s
# Wall time: 1min 9s

# %%
'''
for i in range(0,5):
    validation_set.digits[i].__print__()
'''
# Out:
# '\nfor i in range(0,5):\n    validation_set.digits[i].__print__()\n'

# %%
def cvt_obj_nparray(dataset):
    X = np.zeros((dataset.length, 12))
    Y = np.zeros((dataset.length,))
    for i, digit in enumerate(dataset.digits):
        Y[i] = digit.target
        for j, feature in enumerate(digit.features):
            X[i, j] = digit.features[feature]
    return X, Y

# %%
# %%time

#The X_dataset and Y_dataset are the lists used in the classifier
print("Creating X_dataset and Y_dataset")
X_test, Y_test = cvt_obj_nparray(testing_set)
print("Finished X_dataset and Y_dataset\n")
# Out:
# Creating X_dataset and Y_dataset
# Finished X_dataset and Y_dataset
#
# CPU times: user 32.9 ms, sys: 3.92 ms, total: 36.8 ms
# Wall time: 34.3 ms

# %% [markdown]
# # **KK Neighborhod algorithm**

# %%
def plot_confusion_matrix(clf, data_x, data_y):
    classes = string.ascii_uppercase
    
    Ypred = clf.predict(data_x)
    
    # Computation of confusion matrix on testing set
    cm = confusion_matrix(data_y, Ypred)
    
    plt.figure(figsize=(15,12))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# # Load classifier

# %%
# load first knn classifier
first_classifier = './knn_classifier.sav'
knn_classificator = joblib.load(first_classifier)

# %%
knn_classificator
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# load best knn classifier
best_classifier = './best_knn_classifier.sav'
best_knn_classificator = joblib.load(best_classifier)

# %%
best_knn_classificator
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=29, p=2,
#            weights='distance')

# %%
result = knn_classificator.score(X_test, Y_test)
print(str(round(result * 100, 3)) + "%")
# Out:
# 14.341%

# %%
best_result = best_knn_classificator.score(X_test, Y_test)
print(str(round(best_result * 100, 3)) + "%")
# Out:
# 17.236%

# %%
# Compute prediction accuracy on testing set
def test_knnModel(clf, nom):
    predicted = clf.predict(X_test)
    print("The accuracy for test database is: " + str(round((accuracy_score(Y_test, predicted) * 100), 3)) + "%")

    print("Using: " + str(len(X_test)) + " images")
    
    plot_confusion_matrix(clf, X_test, Y_test)
    plt.title('Test confusion matrix: accuracy of ' + str(round((accuracy_score(Y_test, predicted) * 100), 3)) + "%, used " + str(len(X_test)) + " images")
    plt.savefig(nom)
    #plt.show()

# %%
test_knnModel(knn_classificator, './simple_classifier')
# Out:
# The accuracy for test database is: 14.341%
# Using: 6150 images

# %%
test_knnModel(best_knn_classificator, './best_classifier')
# Out:
# The accuracy for test database is: 17.236%
# Using: 6150 images

# %% [markdown]
# # MINGAU APPLICATION

# %%
# %%time

#Load the database (.npy) files 
img_array_photos = np.load('./../photos/test_photos.npy', allow_pickle=True)
# Out:
# CPU times: user 14.7 ms, sys: 157 µs, total: 14.9 ms
# Wall time: 14.7 ms

# %%
img_array_photos[0]
# Out:
# (29,)

# %%
# %%time 

    
print("Creating validation dataset...")
print("Number of the lines in the validation dataset: " + str(len(img_array_photos)))
photos_set = load_data_set(img_array_photos, 1)
print ("Number of the lines in the validation dataset: " + str(photos_set.length))
print ("\nFinished creating validation dataset\n")
# Out:
# Creating validation dataset...
# Number of the lines in the validation dataset: 156
# -----------------------------------------------------------------------
# ValueError                            Traceback (most recent call last)
# <ipython-input-47-8c3e2bb2bc2e> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'\n    \nprint("Creating validation dataset...")\nprint("Number of the lines in the validation dataset: " + str(len(img_array_photos)))\nphotos_set = load_data_set(img_array_photos, 1)\nprint ("Number of the lines in the validation dataset: " + str(photos_set.length))\nprint ("\\nFinished creating validation dataset\\n")')
#
# /home/morooka/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </home/morooka/.local/lib/python2.7/site-packages/decorator.pyc:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /home/morooka/.local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/morooka/.local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-14-cb5dad385dc5> in load_data_set(array, n)
#       1 # n : percent of the number of lines in the data base use as array set
#       2 def load_data_set(array, n):
# ----> 3     dataset = Dataset(array[:int(n * len(array))], int(n * len(array)))
#       4     return dataset
#
# <ipython-input-13-78824f5c217a> in __init__(self, array, length)
#       4         self.length = length
#       5         self.digits = []
# ----> 6         self.digits = self.createDigits()
#       7         self.raw_features = [[float(f) for f in dig.features.values()] for dig in self.digits]
#       8         self.raw_targets  = [[self.digits[i].target] for i in range(self.length)]
#
# <ipython-input-13-78824f5c217a> in createDigits(self)
#      11         digits = []
#      12         for row in self.array:
# ---> 13             digits.append(Digit(np.array(row[:-1]), row[-1]))
#      14         return digits
#
# <ipython-input-11-d916a5c9e1de> in __init__(self, data, target)
#       3         self.target = target
#       4         self.width  = int(np.sqrt(len(data)))
# ----> 5         self.image  = data.reshape(self.width, self.width)
#       6         self.features = {'var' : 0,
#       7                          'std' : 0,
#
# ValueError: cannot reshape array of size 28 into shape (5,5)

# %%
# %%time

#The X_dataset and Y_dataset are the lists used in the classifier
print("Creating X_dataset and Y_dataset")
X_photos, Y_photos = cvt_obj_nparray(testing_set)
print("Finished X_dataset and Y_dataset\n")
# Out:
# Creating X_dataset and Y_dataset
# Finished X_dataset and Y_dataset
#
# CPU times: user 36.8 ms, sys: 12.5 ms, total: 49.2 ms
# Wall time: 40.3 ms

# %%
for i in range(0,5):
    photos_set.digits[i].__print__()
# Out:
# Digit target: 16.0
# Digit features:
# {'std_grad_M': 184.27556129323344, 'mean_grad_D': -0.06533761297635057, 'std_grad_D': 1.0928542409428887, 'var': 4557.562311276552, 'active_PC_X': 22, 'active_PC_Y': 28, 'std': 67.50972012441284, 'std_PC_X': 11.489125293076057, 'std_PC_Y': 0.0, 'mean_grad_M': 117.2252032597707, 'mean_PC_Y': 22.0, 'mean_PC_X': 22.0}
# Digit image:
# Digit target: 16.0
# Digit features:
# {'std_grad_M': 197.09971011544175, 'mean_grad_D': 0.25053282182908065, 'std_grad_D': 0.5958807754619697, 'var': 5930.657330279051, 'active_PC_X': 28, 'active_PC_Y': 28, 'std': 77.01076113296797, 'std_PC_X': 1.1627728997214075, 'std_PC_Y': 8.267529305441048, 'mean_grad_M': 118.35929708865325, 'mean_PC_Y': 19.071428571428573, 'mean_PC_X': 19.071428571428573}
# Digit image:
# Digit target: 16.0
# Digit features:
# {'std_grad_M': 196.75565456434228, 'mean_grad_D': -0.22745141735168495, 'std_grad_D': 0.5580834872377805, 'var': 5935.072287588505, 'active_PC_X': 28, 'active_PC_Y': 28, 'std': 77.03942034821202, 'std_PC_X': 1.1627728997214075, 'std_PC_Y': 8.267529305441048, 'mean_grad_M': 118.52927371885046, 'mean_PC_Y': 19.071428571428573, 'mean_PC_X': 19.071428571428573}
# Digit image:
# Digit target: 22.0
# Digit features:
# {'std_grad_M': 186.00956569926018, 'mean_grad_D': -0.26567936237503836, 'std_grad_D': 1.0962859239146283, 'var': 4825.947704081633, 'active_PC_X': 22, 'active_PC_Y': 28, 'std': 69.4690413355592, 'std_PC_X': 11.489125293076057, 'std_PC_Y': 0.0, 'mean_grad_M': 119.3920895795506, 'mean_PC_Y': 22.0, 'mean_PC_X': 22.0}
# Digit image:
# Digit target: 22.0
# Digit features:
# {'std_grad_M': 199.44062774846745, 'mean_grad_D': 0.23756369208312195, 'std_grad_D': 0.611441610751563, 'var': 6246.140872292795, 'active_PC_X': 28, 'active_PC_Y': 28, 'std': 79.03253046874303, 'std_PC_X': 1.1627728997214075, 'std_PC_Y': 8.267529305441048, 'mean_grad_M': 121.01116591243382, 'mean_PC_Y': 19.071428571428573, 'mean_PC_X': 19.071428571428573}
# Digit image:
